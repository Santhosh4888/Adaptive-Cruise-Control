# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pathlib import Path

# Path setup (relative to this notebook file) 
notebook_path = Path("plotting.ipynb").resolve()
script_dir = notebook_path.parent 
csv_folder = script_dir / "Auto_Logged_data_April9"

print("Notebook dir:", script_dir)
print("CSV folder:", csv_folder)
# Out:
# Notebook dir: C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026
# CSV folder: C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026\Auto_Logged_data_April9

# %%
# choose files to plot (all CSVs in the folder)
selected_files = sorted([p.name for p in csv_folder.glob("*.csv")])
print("Selected files:")
for f in selected_files:
    print(f)
# Out:
# Selected files:
# Data_Apr9_PD_10kph_FV1.csv
# Data_Apr9_PD_10kph_FV2.csv
# Data_Apr9_PD_10kph_FV3.csv
# Data_Apr9_PD_10kph_FV4.csv
# Data_Apr9_PD_10kph_FV5.csv
# Data_Apr9_PD_5kph_FV1.csv
# Data_Apr9_PD_5kph_FV2.csv
# Data_Apr9_PD_5kph_FV3.csv

# %%
def compute_one_second_acceleration(df, time_col, velocity_col):

    if time_col not in df.columns or velocity_col not in df.columns:
        return pd.Series(np.nan, index=df.index)

    temp = df[[time_col, velocity_col]].copy()
    temp[time_col] = pd.to_numeric(temp[time_col], errors="coerce")
    temp[velocity_col] = pd.to_numeric(temp[velocity_col], errors="coerce")

    # Prefer explicit version
    temp = temp.dropna(subset=[time_col, velocity_col]).sort_values(time_col)

    if temp.empty:
        return pd.Series(np.nan, index=df.index)

    temp["Time_1s"] = np.floor(temp[time_col]).astype(int)

    vel_sec = temp.groupby("Time_1s")[velocity_col].mean()

    time_sec = vel_sec.index.to_series().astype(float)
    dt = time_sec.diff()

    acc_sec = vel_sec.diff() / dt
    acc_sec = acc_sec.fillna(0)

    time_bucket = np.floor(pd.to_numeric(df[time_col], errors="coerce")).astype("Int64")

    return time_bucket.map(acc_sec)

# %%
data = {}
for file in selected_files:
    path = os.path.join(csv_folder, file)
    df = pd.read_csv(path)

    # Check if DataFrame is empty or missing required columns
    if df.empty:
        print(f"Skipping {file}: empty DataFrame")
        continue
    if "Time(s)" not in df.columns:
        print(f"Skipping {file}: missing 'Time(s)' column")
        continue

    
    # normalize time for this file
    df["Time"] = df["Time(s)"] - df["Time(s)"].iloc[0]
    df["Time_1s"] = np.floor(df["Time"]).astype("Int64")

    # Calculate acceleration from velocity (simple finite difference) on raw data (not recommended due to noise)
    df["Ego_Acceleration_raw(m/s^2)"] = df["Ego_Velocity(m/s)"].diff() / df["Time"].diff()
    if "Obs_Velocity(m/s)" in df.columns:
        df["Obs_Acceleration_raw(m/s^2)"] = df["Obs_Velocity(m/s)"].diff() / df["Time"].diff()

    # Calculate acceleration using 1-second intervals
    if "Ego_Velocity(m/s)" in df.columns:
        df["Ego_Acceleration(m/s^2)"] = compute_one_second_acceleration(df, "Time", "Ego_Velocity(m/s)")
    if "Obs_Velocity(m/s)" in df.columns:
        df["Obs_Acceleration(m/s^2)"] = compute_one_second_acceleration(df, "Time", "Obs_Velocity(m/s)") 

    # convert to km/h (and keep the original m/s if you want)
    df["Ego_Velocity_kmph"] = df["Ego_Velocity(m/s)"] * 3.6
    if "Obs_Velocity(m/s)" in df.columns:
        df["Obs_Velocity_kmph"] = df["Obs_Velocity(m/s)"] * 3.6

    data[file] = df

    print(file, "loaded")
    display(df.head())
# Out:
# Data_Apr9_PD_10kph_FV1.csv loaded
#    Ego_Position(m)  Ego_Velocity(m/s)  Obs_Position(m)  Obs_Velocity(m/s)  \
# 0              0.0                0.0              NaN                NaN
# 1              0.0                0.0              NaN                NaN
# 2              0.0                0.0              NaN                NaN
# 3              0.0                0.0              NaN                NaN
# 4              0.0                0.0              NaN                NaN
#
#    Separation(m)  Relative velocity(m/s)   Time(s)      Time  Time_1s  \
# 0            NaN                     NaN  0.000007  0.000000        0
# 1            NaN                     NaN  7.290979  7.290972        7
# 2            NaN                     NaN  7.400624  7.400617        7
# 3            NaN                     NaN  7.510396  7.510390        7
# 4            NaN                     NaN  7.620782  7.620775        7
#
#    Ego_Acceleration_raw(m/s^2)  Obs_Acceleration_raw(m/s^2)  \
# 0                          NaN                          NaN
# 1                          0.0                          NaN
# 2                          0.0                          NaN
# 3                          0.0                          NaN
# 4                          0.0                          NaN
#
#    Ego_Acceleration(m/s^2)  Obs_Acceleration(m/s^2)  Ego_Velocity_kmph  \
# 0                 0.000000                      NaN                0.0
# 1                 0.000567                      NaN                0.0
# 2                 0.000567                      NaN                0.0
# 3                 0.000567                      NaN                0.0
# 4                 0.000567                      NaN                0.0
#
#    Obs_Velocity_kmph
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# Data_Apr9_PD_10kph_FV2.csv loaded
#    Ego_Position(m)  Ego_Velocity(m/s)  Obs_Position(m)  Obs_Velocity(m/s)  \
# 0              0.0                0.0              NaN                NaN
# 1              0.0                0.0              NaN                NaN
# 2              0.0                0.0              NaN                NaN
# 3              0.0                0.0              NaN                NaN
# 4              0.0                0.0              NaN                NaN
#
#    Separation(m)  Relative velocity(m/s)   Time(s)      Time  Time_1s  \
# 0            NaN                     NaN  0.000014  0.000000        0
# 1            NaN                     NaN  7.624651  7.624637        7
# 2            NaN                     NaN  7.734301  7.734288        7
# 3            NaN                     NaN  7.844140  7.844126        7
# 4            NaN                     NaN  7.955156  7.955142        7
#
#    Ego_Acceleration_raw(m/s^2)  Obs_Acceleration_raw(m/s^2)  \
# 0                          NaN                          NaN
# 1                          0.0                          NaN
# 2                          0.0                          NaN
# 3                          0.0                          NaN
# 4                          0.0                          NaN
#
#    Ego_Acceleration(m/s^2)  Obs_Acceleration(m/s^2)  Ego_Velocity_kmph  \
# 0                      0.0                      NaN                0.0
# 1                      0.0                      NaN                0.0
# 2                      0.0                      NaN                0.0
# 3                      0.0                      NaN                0.0
# 4                      0.0                      NaN                0.0
#
#    Obs_Velocity_kmph
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# Data_Apr9_PD_10kph_FV3.csv loaded
#    Ego_Position(m)  Ego_Velocity(m/s)  Obs_Position(m)  Obs_Velocity(m/s)  \
# 0              0.0                0.0              NaN                NaN
# 1              0.0                0.0              NaN                NaN
# 2              0.0                0.0              NaN                NaN
# 3              0.0                0.0              NaN                NaN
# 4              0.0                0.0              NaN                NaN
#
#    Separation(m)  Relative velocity(m/s)   Time(s)      Time  Time_1s  \
# 0            NaN                     NaN  0.000009  0.000000        0
# 1            NaN                     NaN  7.939826  7.939816        7
# 2            NaN                     NaN  8.049802  8.049793        8
# 3            NaN                     NaN  8.159282  8.159273        8
# 4            NaN                     NaN  8.269774  8.269765        8
#
#    Ego_Acceleration_raw(m/s^2)  Obs_Acceleration_raw(m/s^2)  \
# 0                          NaN                          NaN
# 1                          0.0                          NaN
# 2                          0.0                          NaN
# 3                          0.0                          NaN
# 4                          0.0                          NaN
#
#    Ego_Acceleration(m/s^2)  Obs_Acceleration(m/s^2)  Ego_Velocity_kmph  \
# 0                 0.000000                      NaN                0.0
# 1                 0.000000                      NaN                0.0
# 2                 0.040123                      NaN                0.0
# 3                 0.040123                      NaN                0.0
# 4                 0.040123                      NaN                0.0
#
#    Obs_Velocity_kmph
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# Data_Apr9_PD_10kph_FV4.csv loaded
#    Ego_Position(m)  Ego_Velocity(m/s)  Obs_Position(m)  Obs_Velocity(m/s)  \
# 0              0.0                0.0              NaN                NaN
# 1              0.0                0.0              NaN                NaN
# 2              0.0                0.0              NaN                NaN
# 3              0.0                0.0              NaN                NaN
# 4              0.0                0.0              NaN                NaN
#
#    Separation(m)  Relative velocity(m/s)   Time(s)      Time  Time_1s  \
# 0            NaN                     NaN  0.000007  0.000000        0
# 1            NaN                     NaN  7.627453  7.627447        7
# 2            NaN                     NaN  7.737232  7.737226        7
# 3            NaN                     NaN  7.848183  7.848176        7
# 4            NaN                     NaN  7.957405  7.957399        7
#
#    Ego_Acceleration_raw(m/s^2)  Obs_Acceleration_raw(m/s^2)  \
# 0                          NaN                          NaN
# 1                          0.0                          NaN
# 2                          0.0                          NaN
# 3                          0.0                          NaN
# 4                          0.0                          NaN
#
#    Ego_Acceleration(m/s^2)  Obs_Acceleration(m/s^2)  Ego_Velocity_kmph  \
# 0                      0.0                      NaN                0.0
# 1                      0.0                      NaN                0.0
# 2                      0.0                      NaN                0.0
# 3                      0.0                      NaN                0.0
# 4                      0.0                      NaN                0.0
#
#    Obs_Velocity_kmph
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# Data_Apr9_PD_10kph_FV5.csv loaded
#    Ego_Position(m)  Ego_Velocity(m/s)  Obs_Position(m)  Obs_Velocity(m/s)  \
# 0              0.0                0.0              NaN                NaN
# 1              0.0                0.0              NaN                NaN
# 2              0.0                0.0              NaN                NaN
# 3              0.0                0.0              NaN                NaN
# 4              0.0                0.0              NaN                NaN
#
#    Separation(m)  Relative velocity(m/s)   Time(s)      Time  Time_1s  \
# 0            NaN                     NaN  0.000006  0.000000        0
# 1            NaN                     NaN  7.656757  7.656750        7
# 2            NaN                     NaN  7.767513  7.767507        7
# 3            NaN                     NaN  7.877039  7.877033        7
# 4            NaN                     NaN  7.986467  7.986460        7
#
#    Ego_Acceleration_raw(m/s^2)  Obs_Acceleration_raw(m/s^2)  \
# 0                          NaN                          NaN
# 1                          0.0                          NaN
# 2                          0.0                          NaN
# 3                          0.0                          NaN
# 4                          0.0                          NaN
#
#    Ego_Acceleration(m/s^2)  Obs_Acceleration(m/s^2)  Ego_Velocity_kmph  \
# 0                      0.0                      NaN                0.0
# 1                      0.0                      NaN                0.0
# 2                      0.0                      NaN                0.0
# 3                      0.0                      NaN                0.0
# 4                      0.0                      NaN                0.0
#
#    Obs_Velocity_kmph
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# Data_Apr9_PD_5kph_FV1.csv loaded
#    Ego_Position(m)  Ego_Velocity(m/s)  Obs_Position(m)  Obs_Velocity(m/s)  \
# 0              0.0                0.0              NaN                NaN
# 1              0.0                0.0              NaN                NaN
# 2              0.0                0.0              NaN                NaN
# 3              0.0                0.0              NaN                NaN
# 4              0.0                0.0              NaN                NaN
#
#    Separation(m)  Relative velocity(m/s)   Time(s)      Time  Time_1s  \
# 0            NaN                     NaN  0.000015  0.000000        0
# 1            NaN                     NaN  5.361406  5.361390        5
# 2            NaN                     NaN  5.471569  5.471554        5
# 3            NaN                     NaN  5.581330  5.581315        5
# 4            NaN                     NaN  5.692194  5.692179        5
#
#    Ego_Acceleration_raw(m/s^2)  Obs_Acceleration_raw(m/s^2)  \
# 0                          NaN                          NaN
# 1                          0.0                          NaN
# 2                          0.0                          NaN
# 3                          0.0                          NaN
# 4                          0.0                          NaN
#
#    Ego_Acceleration(m/s^2)  Obs_Acceleration(m/s^2)  Ego_Velocity_kmph  \
# 0                      0.0                      NaN                0.0
# 1                      0.0                      NaN                0.0
# 2                      0.0                      NaN                0.0
# 3                      0.0                      NaN                0.0
# 4                      0.0                      NaN                0.0
#
#    Obs_Velocity_kmph
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# Data_Apr9_PD_5kph_FV2.csv loaded
#    Ego_Position(m)  Ego_Velocity(m/s)  Obs_Position(m)  Obs_Velocity(m/s)  \
# 0              0.0                0.0              NaN                NaN
# 1              0.0                0.0              NaN                NaN
# 2              0.0                0.0              NaN                NaN
# 3              0.0                0.0        31.750000       2.070000e-27
# 4              0.0                0.0        31.700001       1.010000e-27
#
#    Separation(m)  Relative velocity(m/s)   Time(s)      Time  Time_1s  \
# 0            NaN                     NaN  0.000006  0.000000        0
# 1            NaN                     NaN  7.362677  7.362671        7
# 2            NaN                     NaN  7.472563  7.472557        7
# 3      31.750000            2.070000e-27  7.583029  7.583022        7
# 4      31.700001            1.010000e-27  7.690994  7.690987        7
#
#    Ego_Acceleration_raw(m/s^2)  Obs_Acceleration_raw(m/s^2)  \
# 0                          NaN                          NaN
# 1                          0.0                          NaN
# 2                          0.0                          NaN
# 3                          0.0                          NaN
# 4                          0.0                -9.817997e-27
#
#    Ego_Acceleration(m/s^2)  Obs_Acceleration(m/s^2)  Ego_Velocity_kmph  \
# 0                      0.0                      NaN                0.0
# 1                      0.0                      0.0                0.0
# 2                      0.0                      0.0                0.0
# 3                      0.0                      0.0                0.0
# 4                      0.0                      0.0                0.0
#
#    Obs_Velocity_kmph
# 0                NaN
# 1                NaN
# 2                NaN
# 3       7.452000e-27
# 4       3.636000e-27
# Data_Apr9_PD_5kph_FV3.csv loaded
#    Ego_Position(m)  Ego_Velocity(m/s)  Obs_Position(m)  Obs_Velocity(m/s)  \
# 0              0.0                0.0              NaN                NaN
# 1              0.0                0.0              NaN                NaN
# 2              0.0                0.0              NaN                NaN
# 3              0.0                0.0              NaN                NaN
# 4              0.0                0.0              NaN                NaN
#
#    Separation(m)  Relative velocity(m/s)   Time(s)      Time  Time_1s  \
# 0            NaN                     NaN  0.000011  0.000000        0
# 1            NaN                     NaN  6.144978  6.144966        6
# 2            NaN                     NaN  6.255000  6.254989        6
# 3            NaN                     NaN  6.364904  6.364893        6
# 4            NaN                     NaN  6.475645  6.475633        6
#
#    Ego_Acceleration_raw(m/s^2)  Obs_Acceleration_raw(m/s^2)  \
# 0                          NaN                          NaN
# 1                          0.0                          NaN
# 2                          0.0                          NaN
# 3                          0.0                          NaN
# 4                          0.0                          NaN
#
#    Ego_Acceleration(m/s^2)  Obs_Acceleration(m/s^2)  Ego_Velocity_kmph  \
# 0                 0.000000                      NaN                0.0
# 1                 0.001157                      NaN                0.0
# 2                 0.001157                      NaN                0.0
# 3                 0.001157                      NaN                0.0
# 4                 0.001157                      NaN                0.0
#
#    Obs_Velocity_kmph
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
for file, df in data.items():
    fig, axes = plt.subplots(3, 1, figsize=(10, 10), sharex=True)

    # ---- Velocity ----
    axes[0].plot(df["Time"], df["Ego_Velocity_kmph"], label="Ego")
    if "Obs_Velocity_kmph" in df.columns:
        axes[0].plot(df["Time"], df["Obs_Velocity_kmph"], linestyle="-", label="Lead")

    # ---- Separation ----
    min_sep = df["Separation(m)"].min() if "Separation(m)" in df.columns else None
    if "Separation(m)" in df.columns:
        axes[1].plot(df["Time"], df["Separation(m)"], label="Separation")
        if min_sep is not None:
            axes[1].axhline(y=min_sep, color="red", linestyle="--", label=f"Min Separation: {min_sep:.2f} m")

    # Minimum safe separation line ( 2 seconds at current speed + min safe distance)
    if "Ego_Velocity_kmph" in df.columns:
        min_sep = df["Ego_Velocity_kmph"] * (1000/3600) * 2 + 1  # 2 seconds gap in meters + min safe distance
        axes[1].plot(df["Time"], min_sep, linestyle="-", color="green", label="Min Safe Separation")

    # Acceleration Raw plot
    if "Ego_Acceleration_raw(m/s^2)" in df.columns:
        axes[2].plot(df["Time"], df["Ego_Acceleration_raw(m/s^2)"], label="Ego (raw)", alpha=0.5)

    # Acceleration plot for averaged dat
    accel_plot_df = df.drop_duplicates("Time_1s") if "Time_1s" in df.columns else df
    if "Ego_Acceleration(m/s^2)" in accel_plot_df.columns:
        axes[2].plot(accel_plot_df["Time_1s"] if "Time_1s" in accel_plot_df.columns else accel_plot_df["Time"],
                     accel_plot_df["Ego_Acceleration(m/s^2)"], label="Ego", color="red")

    axes[0].set_ylabel("Velocity (Kmph)")
    axes[0].set_title(f"Vehicle Velocity — {file}")

    axes[1].set_ylabel("Separation (m)")
    axes[1].set_xlabel("Time (s)")
    axes[1].set_title("Distance to Lead Vehicle")

    axes[2].set_ylabel("Acceleration (m/s^2)")
    axes[2].set_xlabel("Time (s)")
    axes[2].set_title("Ego Acceleration at 1-second Intervals")

    for ax in axes:
        ax.grid()
        ax.legend()

    plt.tight_layout()
    plt.show()

# %%
def clean_velocity_series(v,
                          min_val=0.0,
                          max_val=10.0,         # adjust for your vehicle
                          max_jump=1.0,         # km/h per sample
                          interp_limit=5,
                          rolling_window=5):
    v = pd.to_numeric(v, errors="coerce")
    v.loc[v > 100] = 0.0           # drop garbage high spikes on stop
    v = v.clip(lower=min_val, upper=max_val)
    dv = v.diff().abs()
    v.loc[dv > max_jump] = np.nan # remove spikes
    v = v.interpolate(method="linear", limit=interp_limit, limit_direction="both") # fill short gaps
    v = v.rolling(window=rolling_window, center=True, min_periods=1).median() # smooth
    return v

# %%
def clean_separation_series_timeaware(sep, t, rel_vel_kmph=None,
                                      min_sep=1.0, max_sep=40.0,
                                      base_rate_limit=0.3,   # m/s
                                      rel_vel_gain=0.3,      # extra limit from |relative speed|
                                      median_window=11,
                                      ema_alpha=0.2):
    s = pd.to_numeric(sep, errors="coerce").clip(lower=min_sep, upper=max_sep)
    t = pd.to_numeric(t, errors="coerce")
    dt = t.diff().replace(0, np.nan)

    # Rate-of-change limit in m/s (dynamic from relative speed if available)
    if rel_vel_kmph is not None:
        rv = pd.to_numeric(rel_vel_kmph, errors="coerce").abs() / 3.6
        limit = base_rate_limit + rel_vel_gain * rv
    else:
        limit = base_rate_limit

    dsdt = s.diff().abs() / dt
    s.loc[dsdt > limit] = np.nan

    # Fill short gaps, then robust smooth
    s = s.interpolate(limit=3, limit_direction="both")
    s = s.rolling(median_window, center=True, min_periods=1).median()
    s = s.ewm(alpha=ema_alpha, adjust=False).mean()

    return s

# %% [markdown]
# ## For Following vehicle Scenario

# %%
for file, df in data.items():
    # Clean raw velocity
    df["Ego_Velocity_clean"] = clean_velocity_series(df["Ego_Velocity_kmph"],
                                                     min_val=0.0, max_val=20.0, max_jump=0.2)
    if "Obs_Velocity_kmph" in df.columns:
        df["Obs_Velocity_clean"] = clean_velocity_series(df["Obs_Velocity_kmph"],
                                                         min_val=-0.1, max_val=20.0, max_jump=0.14)
    else:
        df["Obs_Velocity_clean"] = np.nan


    if "Separation(m)" in df.columns:
        rel_vel = None
        if "Obs_Velocity_clean" in df.columns and "Ego_Velocity_clean" in df.columns:
            rel_vel = df["Obs_Velocity_clean"] - df["Ego_Velocity_clean"]

        df["Separation_clean"] = clean_separation_series_timeaware(
            df["Separation(m)"],
            df["Time"],
            rel_vel_kmph=rel_vel
        )
    else:
        df["Separation_clean"] = np.nan

    # Recompute Ego position from clean ego velocity
    dt = df["Time"].diff().fillna(0)
    df["Ego_Position_clean"] = (df["Ego_Velocity_clean"].fillna(0) / 3.6) * dt
    df["Ego_Position_clean"] = df["Ego_Position_clean"].cumsum()
    if "Ego_Position(m)" in df.columns:
        df["Ego_Position_clean"] += df["Ego_Position(m)"].iloc[0]

    # Recompute Obs position via separation
    df["Obs_Position_clean"] = df["Ego_Position_clean"] + df["Separation_clean"]

    # Optionally, nothing is dropped: persist all intermediate
    data[file] = df

# %%
alpha = 0.2

for file, df in data.items():

    prev_obs_vel = np.nan
    prev_obs_pos = np.nan
    prev_sep = np.nan
    prev_ego_vel = np.nan

    for i in range(len(df)):

        obs_vel_r = df.loc[i, "Obs_Velocity_clean"]
        obs_pos_r = df.loc[i, "Obs_Position_clean"]
        ego_pos_i = df.loc[i, "Ego_Position_clean"]
        ego_vel_i = df.loc[i, "Ego_Velocity_clean"]
        time_i = df.loc[i, "Time"]

        # ---- Time step ----
        if i > 0:
            dt = time_i - df.loc[i-1, "Time"]
        else:
            dt = 0

        # ---- Relative velocity filtering ----
        if pd.notna(obs_vel_r) and pd.notna(ego_vel_i):
            rel_vel = obs_vel_r - ego_vel_i

            if pd.notna(prev_obs_vel) and pd.notna(prev_ego_vel):
                prev_rel_vel = prev_obs_vel - prev_ego_vel
                rel_vel_f = alpha * prev_rel_vel + (1 - alpha) * rel_vel
            else:
                rel_vel_f = rel_vel

            obs_vel_f = ego_vel_i + rel_vel_f
        else:
            obs_vel_f = obs_vel_r

        # ---- Position outlier rejection ----
        speed_factor = max(abs(ego_vel_i) if pd.notna(ego_vel_i) else 0,
                           abs(obs_vel_r) if pd.notna(obs_vel_r) else 0) / 3.6
        pos_threshold = 1.5 + 0.3 * speed_factor   # tighter

        if np.isnan(obs_pos_r):
            obs_pos_f = prev_obs_pos
        else:
            if pd.notna(prev_obs_pos) and abs(obs_pos_r - prev_obs_pos) > pos_threshold:
                obs_pos_f = prev_obs_pos
            else:
                obs_pos_f = obs_pos_r

        # ---- Predict position ----
        if pd.notna(prev_obs_pos) and pd.notna(obs_vel_f) and dt > 0:
            predicted_pos = prev_obs_pos + (obs_vel_f / 3.6) * dt

            # tighter prediction constraint
            if pd.notna(obs_pos_f) and abs(obs_pos_f - predicted_pos) > 0.3:
                obs_pos_f = predicted_pos

        # ---- Compute separation (ONLY here) ----
        sep = obs_pos_f - ego_pos_i

        # ---- NEW: Strong spike rejection ----
        if pd.notna(prev_sep) and pd.notna(sep) and dt > 0:

            expected_change = ((prev_obs_vel - prev_ego_vel) / 3.6) * dt if pd.notna(prev_obs_vel) and pd.notna(prev_ego_vel) else 0

            max_jump = 0.5 + 0.2 * abs(expected_change)

            if abs(sep - prev_sep - expected_change) > max_jump:
                sep = prev_sep + expected_change

        # ---- Save values ----
        df.at[i, "Obs_Velocity_clean"] = obs_vel_f
        df.at[i, "Obs_Position_clean"] = obs_pos_f
        df.at[i, "Separation_clean"] = sep

        prev_obs_vel = obs_vel_f
        prev_obs_pos = obs_pos_f
        prev_sep = sep
        prev_ego_vel = ego_vel_i

# %%
# from scipy.signal import savgol_filter

# for file, df in data.items():

#     # Median smoothing (strong spike removal)
#     df["Separation_clean"] = df["Separation_clean"].rolling(
#         window=9, center=True, min_periods=1
#     ).median()

#     # Savitzky-Golay (smooth curve)
#     df["Separation_clean"] = savgol_filter(
#         df["Separation_clean"].fillna(method="ffill").fillna(method="bfill"),
#         window_length=15,
#         polyorder=2
#     )

# %% [markdown]
# ### Saving the cleaned data to new folder for further use.

# %%
output_folder = script_dir / "Processed_Data_April9_PD"
output_folder.mkdir(exist_ok=True)  
for file, df in data.items():
    output_path = output_folder / file
    df.to_csv(output_path, index=False)
    print(f"Saved cleaned data to {output_path}")
# Out:
# Saved cleaned data to C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026\Processed_Data_April9_PD\Data_Apr9_PD_10kph_FV1.csv
# Saved cleaned data to C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026\Processed_Data_April9_PD\Data_Apr9_PD_10kph_FV2.csv
# Saved cleaned data to C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026\Processed_Data_April9_PD\Data_Apr9_PD_10kph_FV3.csv
# Saved cleaned data to C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026\Processed_Data_April9_PD\Data_Apr9_PD_10kph_FV4.csv
# Saved cleaned data to C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026\Processed_Data_April9_PD\Data_Apr9_PD_10kph_FV5.csv
# Saved cleaned data to C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026\Processed_Data_April9_PD\Data_Apr9_PD_5kph_FV1.csv
# Saved cleaned data to C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026\Processed_Data_April9_PD\Data_Apr9_PD_5kph_FV2.csv
# Saved cleaned data to C:\Users\home\Desktop\ACC\Auto-Cruise\Adaptive-Cruise-Control\Adaptive-Cruise-Control\9_Vehicle_Testing_Results\Testing_Using_Radar\April9_2026\Processed_Data_April9_PD\Data_Apr9_PD_5kph_FV3.csv

# %%
for file, df in data.items():
    fig, axes = plt.subplots(2,1,figsize=(10,10), sharex=True)

    axes[0].plot(df["Time"], df["Ego_Velocity_clean"], label="Ego Velocity", linewidth=2)
    # axes[0].plot(df["Time"], df["Ego_Velocity_kmph"], alpha=0.3, label="Ego raw")
    if "Obs_Velocity_clean" in df.columns:
        axes[0].plot(df["Time"], df["Obs_Velocity_clean"], color="orange",linewidth=2, linestyle='--', label="Lead Velocity")
    axes[0].set_ylabel("Velocity (km/h)")
    axes[0].set_title(f"Vehicle Velocity — {file}")
    axes[0].legend()
    axes[0].grid()

    axes[1].plot(df["Time"], df["Separation_clean"], label="Separation between vehicles", linewidth=2)
    minimum_separation = df["Separation_clean"].min()
    axes[1].axhline(minimum_separation, color='red', linestyle='--', label=f'Min Separation: {minimum_separation:.2f} m')
    axes[1].set_ylabel("Separation (m)")
    axes[1].set_xlabel("Time (s)")
    axes[1].legend()
    axes[1].grid()

    # Minimum separation line ( 2 seconds at current speed + min safe distance)
    if "Ego_Velocity_clean" in df.columns:
        min_sep = df["Ego_Velocity_clean"] * (1000/3600) * 2 + 1  # 2 seconds gap in meters + min safe distance
        axes[1].plot(df["Time"], min_sep, linestyle="-", color="green", label="Min Safe Separation")
        axes[1].legend()

    plt.tight_layout()
    plt.show()

# %%
for file, df in data.items():
    plt.figure(figsize=(10,4))
    # plt.plot(df["Time"], df["Ego_Position(m)"], alpha=0.3, label="Ego raw")
    plt.plot(df["Time"], df["Ego_Position_clean"], label="Ego clean", linewidth=2)
    plt.plot(df["Time"], df["Obs_Position_clean"], label="Obs clean", linestyle="--")
    #show the gap between ego and obs as separation and show the value of separation as well
    plt.fill_between(df["Time"], df["Ego_Position_clean"], df["Obs_Position_clean"], color="gray", alpha=0.3, label="Separation")
    # Show the value of separation as text on the plot
    for i in range(0, len(df), max(1, len(df)//10)):  # Show text for up to 10 points
        if pd.notna(df.loc[i, "Separation_clean"]):
            plt.text(df.loc[i, "Time"], df.loc[i, "Ego_Position_clean"] + 0.5, f"{df.loc[i, 'Separation_clean']:.1f} m", fontsize=8, ha='center')       


    plt.legend(); plt.grid(); plt.title(file); plt.show()
